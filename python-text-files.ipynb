# %% [markdown]
# # 2 Categories of Files
#
# * **Text File (ASCII file)**- sequence of lines of so-called electronic text.(doesn't contain metadata)
# * **Binary File** - written in binary

# %%
filename = "/kaggle/input/sourcetxt/source.txt"
filename
# Out:
# '/kaggle/input/sourcetxt/source.txt'

# %%
file = open(filename, mode = 'r')
text = file.read()
text
# Out:
# 'This is the simplest plain text file!\n'

# %%
file.close()

# %%
file.closed
# Out:
# True

# %%
print(text)
# Out:
# This is the simplest plain text file!
