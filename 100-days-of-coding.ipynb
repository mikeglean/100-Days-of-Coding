# %% [markdown]
# # Day 1
# print("Hello world")
#
# " " -> means STRINGS
#
# **Day 1.1 - Printing Assignment**
# * > print("Day 1 - Python Print Function")
# * > print("The function is declared like this:")
# * > print("print('what to print')")
#
# #Lesson learned- dont use double quote in same coding line
#
# \n = can be use for multiple print strings
#
# > print("Hello world!\nHello world!\nHello world!")
#
# **Result:**
#
# Hello world!
#
# Hello world!
#
# Hello world!
#
# **Concatenate:**
#
# > print("Hello"+" "+"Mike")
#
# **Result:**
#
# HelloMike
#
# **Day 1.2 - Debugging Practice**
#
# * > print("Day 1 - String Manipulation")
# * > print('String Concatenation is done with the "+" sign.')
# * > print('e.g. print("Hello " + "world")')
# * > print("New lines can be created with a backslash and n.")
#
# **Result:**
#
# Day 1 - String Manipulation
#
# String Concatenation is done with the "+" sign.
#
# e.g. print("Hello " + "world")
#
# New lines can be created with a backslash and n.
#
# **Input function**
#
# > #This is a comment
# print("Hello " + input("What is your name?"))
#
# **Comment function**
#
# Use # to add comments in the code (Shortcut= Ctrl + /)
#
# **Day 1.3 - Inputs**
#
# #len - to count the length of the string
#
# > print(len(input('What is your name? ')))
#
# **Day 1.4 - Variables
#
# > name = input("What is your name?")
# > print(name)
#
# Revising the answer in 1.3 using variables
#
# > name = input('What is your name? ')
#
# > length = len(name)
#
# > print(length)
#
# Variables exercise:
# > # 🚨 Don't change the code below 👇
#
# > a = input("a: ")
#
# > b = input("b: ")
#
# > # 🚨 Don't change the code above 👆
#
# >
# > ####################################
# > #Write your code below this line 👇
#
# > c = a
#
# > a = b
#
# > b = c
#
# >
# >
# >
# > #Write your code above this line 👆
# > ####################################
# >
# > # 🚨 Don't change the code below 👇
#
# > print("a: " + a)
#
# > print("b: " + b)
#
# **Day 1.5 - Variables Naming
#
# name of the variable can be separated by underscore "_"
#
# function name cannot be used as variable name
#
# **Day 1 - Project (BAND NAME GENERATOR)
#
# Code:
# > print("Welcome to the Band Name Generator.")
# >
# > city = input("What's the name of the city you grew up in?\n")
# >
# > pet_name = input("What's the name of your pet?\n")
# >
# > print("Your band name could be " + city + " " + pet_name)

# %% [markdown]
# # Day 2
#
# **Data Types**
# * String - "Hello", "1234"
# * Subscripting - [0]H [1]E (Programming always starts with 0)
# * Integer - whole numbers (no decimal places) 123
# * Float - numbers with decimal places 3.14267581
# * Boolean - True / False
#
# **Type Error, Type Checking and Type Conversion**
# > type()
# > type(num_char)
#
# num_char = len(input("What is your name?\n"))
#
# num_char_2 = str(num_char)
#
# print("Your name has " + num_char_2 + " characters.")
#
# **2.1 Data Types Exercise**
#
# > two_digit_number = input("Type a two digit number: ")
#
# > a = int(two_digit_number[0])
#
# > b = int(two_digit_number[1])
#
# > print(a + b)
#
#
# **2.2 Data Types Exercise**
#
# Mathematical operations (+, -, *, /)
#
# Additional operation (Exponential **)
#
# Division always result to "Float"
#
# Order priority (PEMDAS)
#
# > # 🚨 Don't change the code below 👇
#
# > height = input("enter your height in m: ")
#
# > weight = input("enter your weight in kg: ")
#
# > # 🚨 Don't change the code above 👆
# >
# > #Write your code below this line 👇
#
# > a = float(height)
#
# > b = float(weight)
# >
# > print(int(b / (a*a)))
#
#
# **2.2 Number manipulation**
# > a = 2
# >
# > a += 2
# >
# > print(a)
# >
#
# Result = 4
#
# Combining different data types
#
# Using **F-String**
# > age = 23
#
# > height = 1.5
# >
# > isWinning = True
# >
# >
# > #f-string
# > print (f"Your age is {age}, your height is {height}, you are winning is {isWinning}")
# >
#
# Answer:
#
# > # 🚨 Don't change the code below 👇
#
# > age = input("What is your current age? ")
#
# > # 🚨 Don't change the code above 👆
# >
# > #Write your code below this line 👇
#
# > age_int = int(age)
#
# > years_left = (90 - (age_int))
#
# > days = 365 * (years_left)
#
# > weeks = 52 * (years_left)
#
# > months = 12 * (years_left)
# >
# > print (f"You have {days} days, {weeks} weeks, and {months} months left.")
#
# **Day 2 Project - Tip Calculator**
#
# print("Welcome to the tip calculator.")
#
# total_bill = float(input("What was the total bill? $"))
#
# tip = float(input("What percentage tip would you like to give? 10, 12, or 15? "))
#
# split = float(input("How many people to split the bill? "))
#
# tip_percentage = 1 + (tip / 100)
#
# pay = (total_bill * tip_percentage / split)
#
# round_pay = round(pay , 2)
#
# print(f"Each person should pay: ${round_pay}")

# %% [markdown]
# # Day 3
#
# **CONTROL FLOW AND LOGICAL OPERATOR**
#
# > Always check the indentation
#
# > "IF" and "ELSE:" must be aligned
#
# > Greater than equal : >=
#
# > Greater than : >
#
# > Less than : <
#
# > Equal to : ==
#
# > Module/Remainder : %
#
# **3.1 Odd or Even exercise**
#
# Answer:
#
# if number % 2 == 0:
#
#   print("This is an even number.")
#
# else:
#
#   print("This is an odd number.")
#
#
#
# **Nested if/else**
# **if / elif/ else
#
# if condition1:
#
#     do A
#
#     elif condition2:
#
#     do B
#
#     else:
#
#     do this
#
#
# Sample:
# height = int(input("What is your height?"))
#
# if height >= 120:
#
#   print("You can ride the rollercoaster!")
#
#   age = int(input("What is your age?"))
#
#   if age < 12:
#
#     print("Please pay $5.00")
#
#   elif age <= 18:
#
#     print("Please pay $7.00")
#
#   else:
#     print("Please pay $12.00")
#
# else:
#
#   print("Sorry, you have to grow taller before you can ride.")
#
#
#  **3.1 Leap Year Exercise**
#
#  if year % 4 == 0:
#
#   if year % 100 == 0:
#
#     if year % 400 == 0:
#
#       print("Leap year.")
#
#     else:
#
#       print("Not leap year.")
#
#   else:
#
#     print("Leap year.")
#
# else:
#
#   print("Not leap year.")
#
#
#  **MULTIPLE IFS**
#
#  print("Welcome to the rollercoaster!")
#
# height = int(input("What is your height?"))
#
# bill = 0
#
#
# if height >= 120:
#
#   print("You can ride the rollercoaster!")
#
#   age = int(input("What is your age?"))
#
#   if age < 12:
#
#     bill = 5
#
#     print("Please pay $5.00")
#
#   elif age <= 18:
#
#     bill = 7
#
#     print("Please pay $7.00")
#
#   else:
#
#     bill = 12
#
#     print("Please pay $12.00")
#
#   wants_photo = input("Do you want a photo taken? Y or N.")
#
#   if wants_photo == "Y":
#
#     bill += 3
#
#   print(f"Your final bill is ${bill}")
#
# else:
#
#   print("Sorry, you have to grow taller before you can ride.")
#
# <span style="background-color: #FFFF00">**Exercise 4 - Pizza Order Practice**</span>
# ![Day 3.4](https://i.imgur.com/0zdg3ge.png)
#
# <span style="background-color: #FFFF00">**Day 3.4 - Logical Operators**</span>
# ![Day 3.5](https://i.imgur.com/tyy0K01.png)
#
# <span style="background-color: #FFFF00">**Day 3.5 - Project**</span>
# ![Day 3.project](https://i.imgur.com/F6nveV3.png)

# %% [markdown]
# # Day 4
#
# **Randomization and Python List**
#
#
# Create new file by adding .py in the filename
#
# **4.1 Heads or Tails**
# ![Answer](https://i.imgur.com/eAdhTYh.png)
#
# **Understanding the Offset and Appending Items to Lists**
#
# states_of_america = ["State1", "State2", "State3", "State4"]
#
# #can use positive/negative index
# states_of_america[2]
# states_of_america[-3]
#
# Can alter by using this syntax
# states_of_america[2] = "State_two"
#
# append() - can use to add item in the end of the list
# len() - use to count the number of items in the list
#
# **4.2 Banker Roulette s**
# ![4.2.answer](https://i.imgur.com/ctefzrj.png)
#
# **IndexErrors and Working with Nested Lists**
#
# - when it exceeds on the number of len
#
# **4.3 Treasure map**
# ![4.3](https://i.imgur.com/xoY1QiQ.png)
#
# **4 Rock Paper Scissors**
# ![4.4.1](https://i.imgur.com/D1XeOHn.png)
#
# ![4.4.2](https://i.imgur.com/yR7UPiy.png)
#
#
# Alternative:
#
# game_images = [rock, paper, scissors]
# print(game_images[user_choice])

# %% [markdown]
# # Day 5 - Python Loops
#
# **Looping**
#
# fruits = ["Apple", "Peach", "Pear"]
#
# for fruit in fruits:
#
#   print(fruit)
#
# **Average Height**
# ![5.1](https://i.imgur.com/fYj8v4z.png)
#
# **Highest Score**
# ![5.2](https://i.imgur.com/xXXu5cm.png)
#
# **FOR RANGE**
#
# ![5.3](https://i.imgur.com/dlIpctx.png)
#
# **FIZBUZZ**
#
# ![5.4](https://i.imgur.com/R01x5Ow.png)
#
# ** Password Generator **
#
# ![5.project](https://i.imgur.com/JforMDI.png)

# %% [markdown]
# # Day 6
#
# **Functions**
#
# def my_function():
#
#     #do this
#
#     #then do this
#
#     #finally do this
#
# call it by: my_function()
#
# **Indentation**
#
# You should use 4 spaces for intendation, not tabs.
#
# **While**
#
# while something_true:
#
#     #do this
#
#     #then do this
#
#     #finally do this
#
#     https://reeborg.ca/reeborg.html?lang=en&mode=python&menu=worlds%2Fmenus%2Freeborg_intro_en.json&name=problem_world3.json&url=user_world%3Aproblem_world3.json

# %% [markdown]
# # Day 7
#
# **HANGMAN**
#
# new code learn:
#
# CLEAR
#
# from replit import clear

# %% [markdown]
# # Day 8
#
# **CAESAR CIPHER**
#
# **Function with Inputs**
#
# def my_function(something)
#
#     do this
#
#     do this 2
#
#     do this 3
#
#
#  something = 123
#
#  something : parameter
#
#  123 : argument
#
# Sample:
#
# def greet_input(name):
#
#     print(f"Hello {name}")
#
#     print(f"How do you do {name}")
#
#
# greet_input("Mike")
#
#
# using multiple argument:
#
# def greet_with**(name,location)**:
#
#     print(name)
#
#     print(location)
#
#
# greet_with**("Mike", "Laguna")**
#
#
# or greet_with(location = "Laguna", name = "Mike")
#
# **Round up**
#
# import math
#
# print(math.ceil(xxx))
#
#
# **Prime number checker**
# ![8.2](https://i.imgur.com/MMqfSeS.png)
#
# **Encrypting**
#
# ![8.5](https://i.imgur.com/JiSty5r.png)
#
# **Decrypting**
#
# ![8.6](https://i.imgur.com/weijPlh.png)
#
# **Cleaning up previous codes**
#
# ![8.7](https://i.imgur.com/tJZIj1X.png)
