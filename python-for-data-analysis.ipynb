# %% [markdown]
# **Business** - organization that exists to make money
#
# **Data** - information gathered for reference
#
# **Qualitative Data** - form of text and descriptive in nature (not a number)
#
# **Quantitative Data** - numeric data
#
# **Analysis** - sepaaration of a whole data into smaaller, digestable components to be studied individually, any dataset that contains past data
#
# **Analytics** - future performance -> analysis + logical and computational reasoning
#
# **Business Intelligence** - studies the past of a company, analyzing relational databases
#
# **Data Science** - often involves machine learning, advance statistics and regression analysis

# %% [markdown]
# matrix - [x,y,z], [x,y,z]
#
# vector - [x, y]
#
# scalar = point

# %%
#Sample Matrix

import numpy as np

m = np.array([[5,12,6],[-3,0,14]])
m
# Out:
# array([[ 5, 12,  6],
#        [-3,  0, 14]])

# %%
m.shape
# Out:
# (2, 3)

# %%
type(m)
# Out:
# numpy.ndarray

# %%
v = np.array([5, 2, 7])
v
# Out:
# array([5, 2, 7])

# %%
v.shape
# Out:
# (3,)
